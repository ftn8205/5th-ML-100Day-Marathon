# %% [markdown]
# ## 作業
# 礙於不是所有同學都有 GPU ，這邊的範例使用的是簡化版本的 ResNet，確保所有同學都能夠順利訓練!
#
#
# 最後一天的作業請閱讀這篇非常詳盡的[文章](https://blog.gtwang.org/programming/keras-resnet-50-pre-trained-model-build-dogs-cats-image-classification-system/)，基本上已經涵蓋了所有訓練　CNN 常用的技巧，請使用所有學過的訓練技巧，盡可能地提高 Cifar-10 的 test data 準確率，截圖你最佳的結果並上傳來完成最後一次的作業吧!
#
# 另外這些技巧在 Kaggle 上也會被許多人使用，更有人會開發一些新的技巧，例如使把預訓練在 ImageNet 上的模型當成 feature extractor 後，再拿擷取出的特徵重新訓練新的模型，這些技巧再進階的課程我們會在提到，有興趣的同學也可以[參考](https://www.kaggle.com/insaff/img-feature-extraction-with-pretrained-resnet)

# %%
import tensorflow as tf
import numpy as np
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

config = tf.compat.v1.ConfigProto()

config.gpu_options.per_process_gpu_memory_fraction = 1
sess = tf.compat.v1.Session(config=config)

# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# 訓練用的超參數
batch_size = 1024  
epochs = 5
data_augmentation = True
num_classes = 10

# 資料標準化的方式，此處使用減去所有影像的平均值
subtract_pixel_mean = True

# %%
n = 9 # 使用 ResNet-56 的網路架構

# 使用的 ResNet 模型版本
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# 計算不同 ResNet 版本對應的網路深度，此處都是根據 paper 的定義來計算
depth = n * 6 + 2

# 模型的名稱
model_type = 'ResNet%dv%d' % (depth, version)

# 讀取 Cifar-10 資料集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# 影像輸入的維度
input_shape = x_train.shape[1:]

# 先把影像縮放到 0-1 之間
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# 再減去所有影像的平均值
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean 
    x_test -= x_train_mean # 此處要注意！測試資料也是減去訓練資料的平均值來做標準化，不可以減測試資料的平均值 (因為理論上你是不能知道測試資料的平均值的！)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# 對 label 做 one-hot encoding
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# 學習率動態調整。當跑到第幾個 epcoh 時，根據設定修改學習率。這邊的數值都是參考原 paper
def lr_schedule(epoch):

    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# 使用 resnet_layer 來建立我們的 ResNet 模型
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):

    # 建立卷積層
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    # 對輸入進行卷機，根據 conv_first 來決定 conv. bn, activation 的順序
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# Resnet v1 共有三個 stage，每經過一次 stage，影像就會變小一半，但 channels 數量增加一倍。ResNet-20 代表共有 20 層 layers，疊越深參數越多
def resnet_v1(input_shape, depth, num_classes=10):
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # 模型的初始設置，要用多少 filters，共有幾個 residual block （組成 ResNet 的單元）
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)
    
    # 建立 Input layer
    inputs = Input(shape=input_shape)
    
    # 先對影像做第一次卷機
    x = resnet_layer(inputs=inputs)
    
    # 總共建立 3 個 stage
    for stack in range(3):
        # 每個 stage 建立數個 residual blocks (數量視你的層數而訂，越多層越多 block)
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y]) # 此處把 featuremaps 與 上一層的輸入加起來 (欲更了解結構需閱讀原論文)
            x = Activation('relu')(x)
        num_filters *= 2

    # 建立分類
    # 使用 average pooling，且 size 跟 featuremaps 的 size 一樣 （相等於做 GlobalAveragePooling）
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    
    # 接上 Dense layer 來做分類
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # 建立模型
    model = Model(inputs=inputs, outputs=outputs)
    return model

# 建立 ResNet v1 模型
model = resnet_v1(input_shape=input_shape, depth=depth)

# 編譯模型，使用 Adam 優化器並使用學習率動態調整的函數，０代表在第一個 epochs
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# 使用動態調整學習率
lr_scheduler = LearningRateScheduler(lr_schedule)

# 使用自動降低學習率 (當 validation loss 連續 5 次沒有下降時，自動降低學習率)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
# 設定 callbacks
callbacks = [lr_reducer, lr_scheduler]


print('Using real-time data augmentation.')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Learning rate:  0.001
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 32, 32, 16)   448         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 32, 32, 16)   64          conv2d_228[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 32, 32, 16)   0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 32, 32, 16)   2320        activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 32, 32, 16)   64          conv2d_229[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 32, 32, 16)   0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 32, 32, 16)   2320        activation_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 32, 32, 16)   64          conv2d_230[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 32, 32, 16)   0           activation_220[0][0]
#                                                                  batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 32, 32, 16)   0           add_108[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 32, 32, 16)   2320        activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 32, 32, 16)   64          conv2d_231[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 32, 32, 16)   0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 32, 32, 16)   2320        activation_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 32, 32, 16)   64          conv2d_232[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 32, 32, 16)   0           activation_222[0][0]
#                                                                  batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 32, 32, 16)   0           add_109[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 32, 32, 16)   2320        activation_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 32, 32, 16)   64          conv2d_233[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 32, 32, 16)   0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 32, 32, 16)   2320        activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 32, 32, 16)   64          conv2d_234[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 32, 32, 16)   0           activation_224[0][0]
#                                                                  batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 32, 32, 16)   0           add_110[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 32, 32, 16)   2320        activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 32, 32, 16)   64          conv2d_235[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 32, 32, 16)   0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 32, 32, 16)   2320        activation_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 32, 32, 16)   64          conv2d_236[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 32, 32, 16)   0           activation_226[0][0]
#                                                                  batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 32, 32, 16)   0           add_111[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 32, 32, 16)   2320        activation_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 32, 32, 16)   64          conv2d_237[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 32, 32, 16)   0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 32, 32, 16)   2320        activation_229[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 32, 32, 16)   64          conv2d_238[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, 32, 32, 16)   0           activation_228[0][0]
#                                                                  batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 32, 32, 16)   0           add_112[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 32, 32, 16)   2320        activation_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 32, 32, 16)   64          conv2d_239[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 32, 32, 16)   0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 32, 32, 16)   2320        activation_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 32, 32, 16)   64          conv2d_240[0][0]
# __________________________________________________________________________________________________
# add_113 (Add)                   (None, 32, 32, 16)   0           activation_230[0][0]
#                                                                  batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 32, 32, 16)   0           add_113[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 32, 32, 16)   2320        activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 32, 32, 16)   64          conv2d_241[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 32, 32, 16)   0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 32, 32, 16)   2320        activation_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 32, 32, 16)   64          conv2d_242[0][0]
# __________________________________________________________________________________________________
# add_114 (Add)                   (None, 32, 32, 16)   0           activation_232[0][0]
#                                                                  batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 32, 32, 16)   0           add_114[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 32, 32, 16)   2320        activation_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 32, 32, 16)   64          conv2d_243[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 32, 32, 16)   0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 32, 32, 16)   2320        activation_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 32, 32, 16)   64          conv2d_244[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, 32, 32, 16)   0           activation_234[0][0]
#                                                                  batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 32, 32, 16)   0           add_115[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 32, 32, 16)   2320        activation_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 32, 32, 16)   64          conv2d_245[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 32, 32, 16)   0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 32, 32, 16)   2320        activation_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 32, 32, 16)   64          conv2d_246[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, 32, 32, 16)   0           activation_236[0][0]
#                                                                  batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 32, 32, 16)   0           add_116[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 16, 16, 32)   4640        activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 16, 16, 32)   128         conv2d_247[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 16, 16, 32)   0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 16, 16, 32)   9248        activation_239[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 16, 16, 32)   544         activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 16, 16, 32)   128         conv2d_248[0][0]
# __________________________________________________________________________________________________
# add_117 (Add)                   (None, 16, 16, 32)   0           conv2d_249[0][0]
#                                                                  batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 16, 16, 32)   0           add_117[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 16, 16, 32)   9248        activation_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 16, 16, 32)   128         conv2d_250[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 16, 16, 32)   0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 16, 16, 32)   9248        activation_241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 16, 16, 32)   128         conv2d_251[0][0]
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, 16, 16, 32)   0           activation_240[0][0]
#                                                                  batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 16, 16, 32)   0           add_118[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 16, 16, 32)   9248        activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 16, 16, 32)   128         conv2d_252[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 16, 16, 32)   0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 16, 16, 32)   9248        activation_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 16, 16, 32)   128         conv2d_253[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, 16, 16, 32)   0           activation_242[0][0]
#                                                                  batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 16, 16, 32)   0           add_119[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 16, 16, 32)   9248        activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 16, 16, 32)   128         conv2d_254[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 16, 16, 32)   0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 16, 16, 32)   9248        activation_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 16, 16, 32)   128         conv2d_255[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 16, 16, 32)   0           activation_244[0][0]
#                                                                  batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 16, 16, 32)   0           add_120[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 16, 16, 32)   9248        activation_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 16, 16, 32)   128         conv2d_256[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 16, 16, 32)   0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 16, 16, 32)   9248        activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 16, 16, 32)   128         conv2d_257[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, 16, 16, 32)   0           activation_246[0][0]
#                                                                  batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 16, 16, 32)   0           add_121[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 16, 16, 32)   9248        activation_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 16, 16, 32)   128         conv2d_258[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 16, 16, 32)   0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 16, 16, 32)   9248        activation_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 16, 16, 32)   128         conv2d_259[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, 16, 16, 32)   0           activation_248[0][0]
#                                                                  batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 16, 16, 32)   0           add_122[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 16, 16, 32)   9248        activation_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 16, 16, 32)   128         conv2d_260[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 16, 16, 32)   0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 16, 16, 32)   9248        activation_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 16, 16, 32)   128         conv2d_261[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, 16, 16, 32)   0           activation_250[0][0]
#                                                                  batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 16, 16, 32)   0           add_123[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 16, 16, 32)   9248        activation_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 16, 16, 32)   128         conv2d_262[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 16, 16, 32)   0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 16, 16, 32)   9248        activation_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 16, 16, 32)   128         conv2d_263[0][0]
# __________________________________________________________________________________________________
# add_124 (Add)                   (None, 16, 16, 32)   0           activation_252[0][0]
#                                                                  batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 16, 16, 32)   0           add_124[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 16, 16, 32)   9248        activation_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 16, 16, 32)   128         conv2d_264[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 16, 16, 32)   0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 16, 16, 32)   9248        activation_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 16, 16, 32)   128         conv2d_265[0][0]
# __________________________________________________________________________________________________
# add_125 (Add)                   (None, 16, 16, 32)   0           activation_254[0][0]
#                                                                  batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 16, 16, 32)   0           add_125[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 8, 8, 64)     18496       activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 8, 8, 64)     256         conv2d_266[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 8, 8, 64)     0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 8, 8, 64)     36928       activation_257[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 8, 8, 64)     2112        activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 8, 8, 64)     256         conv2d_267[0][0]
# __________________________________________________________________________________________________
# add_126 (Add)                   (None, 8, 8, 64)     0           conv2d_268[0][0]
#                                                                  batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 8, 8, 64)     0           add_126[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 8, 8, 64)     36928       activation_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 8, 8, 64)     256         conv2d_269[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 8, 8, 64)     0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 8, 8, 64)     36928       activation_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 8, 8, 64)     256         conv2d_270[0][0]
# __________________________________________________________________________________________________
# add_127 (Add)                   (None, 8, 8, 64)     0           activation_258[0][0]
#                                                                  batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 8, 8, 64)     0           add_127[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 8, 8, 64)     36928       activation_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 8, 8, 64)     256         conv2d_271[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 8, 8, 64)     0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 8, 8, 64)     36928       activation_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 8, 8, 64)     256         conv2d_272[0][0]
# __________________________________________________________________________________________________
# add_128 (Add)                   (None, 8, 8, 64)     0           activation_260[0][0]
#                                                                  batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 8, 8, 64)     0           add_128[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 8, 8, 64)     36928       activation_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 8, 8, 64)     256         conv2d_273[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 8, 8, 64)     0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 8, 8, 64)     36928       activation_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 8, 8, 64)     256         conv2d_274[0][0]
# __________________________________________________________________________________________________
# add_129 (Add)                   (None, 8, 8, 64)     0           activation_262[0][0]
#                                                                  batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 8, 8, 64)     0           add_129[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 8, 8, 64)     36928       activation_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 8, 8, 64)     256         conv2d_275[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 8, 8, 64)     0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 8, 8, 64)     36928       activation_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 8, 8, 64)     256         conv2d_276[0][0]
# __________________________________________________________________________________________________
# add_130 (Add)                   (None, 8, 8, 64)     0           activation_264[0][0]
#                                                                  batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 8, 8, 64)     0           add_130[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 8, 8, 64)     36928       activation_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 8, 8, 64)     256         conv2d_277[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 8, 8, 64)     0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 8, 8, 64)     36928       activation_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 8, 8, 64)     256         conv2d_278[0][0]
# __________________________________________________________________________________________________
# add_131 (Add)                   (None, 8, 8, 64)     0           activation_266[0][0]
#                                                                  batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 8, 8, 64)     0           add_131[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 8, 8, 64)     36928       activation_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 8, 8, 64)     256         conv2d_279[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 8, 8, 64)     0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 8, 8, 64)     36928       activation_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 8, 8, 64)     256         conv2d_280[0][0]
# __________________________________________________________________________________________________
# add_132 (Add)                   (None, 8, 8, 64)     0           activation_268[0][0]
#                                                                  batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 8, 8, 64)     0           add_132[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 8, 8, 64)     36928       activation_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 8, 8, 64)     256         conv2d_281[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 8, 8, 64)     0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 8, 8, 64)     36928       activation_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 8, 8, 64)     256         conv2d_282[0][0]
# __________________________________________________________________________________________________
# add_133 (Add)                   (None, 8, 8, 64)     0           activation_270[0][0]
#                                                                  batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 8, 8, 64)     0           add_133[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 8, 8, 64)     36928       activation_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 8, 8, 64)     256         conv2d_283[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 8, 8, 64)     0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 8, 8, 64)     36928       activation_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 8, 8, 64)     256         conv2d_284[0][0]
# __________________________________________________________________________________________________
# add_134 (Add)                   (None, 8, 8, 64)     0           activation_272[0][0]
#                                                                  batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 8, 8, 64)     0           add_134[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 64)     0           activation_274[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           650         flatten_4[0][0]
# ==================================================================================================
# Total params: 861,770
# Trainable params: 857,706
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
# ResNet56v1
# Using real-time data augmentation.

# %%
datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)

# 將資料送進 ImageDataGenrator 中做增強
datagen.fit(x_train)

# %%
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train)//batch_size),
                    validation_data=(x_test, y_test),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)

scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Learning rate:  0.001
# Epoch 1/5
# 48/48 [==============================] - 1560s 33s/step - loss: 2.6507 - accuracy: 0.2729 - val_loss: 3.2280 - val_accuracy: 0.1875
# Learning rate:  0.001
# Epoch 2/5
# 48/48 [==============================] - 1679s 35s/step - loss: 1.9591 - accuracy: 0.4345 - val_loss: 2.8262 - val_accuracy: 0.1937
# Learning rate:  0.001
# Epoch 3/5
# 48/48 [==============================] - 1299s 27s/step - loss: 1.7555 - accuracy: 0.5120 - val_loss: 3.4093 - val_accuracy: 0.1668
# Learning rate:  0.001
# Epoch 4/5
# 48/48 [==============================] - 1521s 32s/step - loss: 1.6204 - accuracy: 0.5612 - val_loss: 2.9026 - val_accuracy: 0.2742
# Learning rate:  0.001
# Epoch 5/5
# 48/48 [==============================] - 1462s 30s/step - loss: 1.4927 - accuracy: 0.6087 - val_loss: 2.7917 - val_accuracy: 0.3125
# 313/313 [==============================] - 39s 125ms/step - loss: 2.7917 - accuracy: 0.3125
# Test loss: 2.7916929721832275
# Test accuracy: 0.3125
