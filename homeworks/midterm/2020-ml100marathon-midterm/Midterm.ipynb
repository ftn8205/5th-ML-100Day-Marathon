# %%
import copy
import warnings
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier

# %%
df_train = pd.read_csv('./train_data.csv')
df_train
# Out:
#                      name      bonus  deferral_payments  deferred_income  \
# 0          RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1      SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2              SHELBY REX   200000.0                NaN          -4167.0
# 3        KOPPER MICHAEL J   800000.0                NaN              NaN
# 4    CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
# ..                    ...        ...                ...              ...
# 108         STABLER FRANK   500000.0                NaN              NaN
# 109         BROWN MICHAEL        NaN                NaN              NaN
# 110      PICKERING MARK R   300000.0                NaN              NaN
# 111          HAUG DAVID L        NaN                NaN              NaN
# 112     SHAPIRO RICHARD S   650000.0                NaN              NaN
#
#      director_fees                 email_address  exercised_stock_options  \
# ...

# %%
df_test = pd.read_csv('./test_features.csv')
df_answer = pd.DataFrame()
df_answer['name'] = df_test['name']
df_test
# Out:
#                     name       bonus  deferral_payments  deferred_income  \
# 0       BELDEN TIMOTHY N   5249999.0          2144013.0       -2334434.0
# 1     BOWEN JR RAYMOND M   1350000.0                NaN           -833.0
# 2         HANNON KEVIN P   1500000.0                NaN       -3117011.0
# 3       DELAINEY DAVID W   3000000.0                NaN              NaN
# 4       CAUSEY RICHARD A   1000000.0                NaN        -235000.0
# 5       HICKERSON GARY J   1700000.0                NaN              NaN
# 6         FREVERT MARK A   2000000.0          6426990.0       -3367011.0
# 7            CHAN RONNIE         NaN                NaN         -98784.0
# 8   DONAHUE JR JEFFREY M    800000.0                NaN        -300000.0
# 9      REYNOLDS LAWRENCE    100000.0            51365.0        -200000.0
# 10      HORTON STANLEY C         NaN          3131860.0              NaN
# 11         LEWIS RICHARD         NaN                NaN              NaN
# ...

# %%
# 把訓練級的label取出來並把true,false轉成0,1的格式

train_y = df_train['poi']
df_train = df_train.drop(['poi'],axis=1)
train_y = LabelEncoder().fit_transform(train_y)

# %%
df = pd.concat([df_train, df_test])
df
# Out:
#                     name      bonus  deferral_payments  deferred_income  \
# 0         RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1     SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2             SHELBY REX   200000.0                NaN          -4167.0
# 3       KOPPER MICHAEL J   800000.0                NaN              NaN
# 4   CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
# ..                   ...        ...                ...              ...
# 28       BIBI PHILIPPE A  1000000.0                NaN              NaN
# 29       SHERRIFF JOHN R  1500000.0                NaN              NaN
# 30          GIBBS DANA R        NaN           504610.0              NaN
# 31        LINDHOLM TOD A   200000.0           204075.0              NaN
# 32       MCMAHON JEFFREY  2600000.0                NaN              NaN
#
#     director_fees                 email_address  exercised_stock_options  \
# ...

# %%
num_features = []
for dtype,feature in zip(df.dtypes,df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
df = df[num_features]


train_num = train_y.shape[0]
df
# Out:
#         bonus  deferral_payments  deferred_income  director_fees  \
# 0   1750000.0                NaN       -3504386.0            NaN
# 1   5600000.0                NaN              NaN            NaN
# 2    200000.0                NaN          -4167.0            NaN
# 3    800000.0                NaN              NaN            NaN
# 4   1250000.0                NaN        -262500.0            NaN
# ..        ...                ...              ...            ...
# 28  1000000.0                NaN              NaN            NaN
# 29  1500000.0                NaN              NaN            NaN
# 30        NaN           504610.0              NaN            NaN
# 31   200000.0           204075.0              NaN            NaN
# 32  2600000.0                NaN              NaN            NaN
#
#     exercised_stock_options  expenses  from_messages  from_poi_to_this_person  \
# 0                19794175.0   46950.0           18.0                     42.0
# ...

# %%
df_m1 = df.fillna(-1)
df_m1 = StandardScaler().fit_transform(df_m1)
train_x = df_m1[:train_num]
test_x = df_m1[train_num:]
estimator = LogisticRegression()

# %%
cross_val_score(estimator,train_x,train_y,cv=10).mean()
# Out:
# 0.8787878787878787

# %%
# test_feature = []
# for dtype,feature in zip(df_test.dtypes,df_test.columns):
#     if dtype == 'float64' or dtype == 'int64':
#         test_feature.append(feature)
# df_test = df_test[test_feature]
# df_test = df_test.fillna(-1)
# test_x = StandardScaler().fit_transform(df_test)

estimator.fit(train_x,train_y)
y_prediction = estimator.predict_proba(test_x)[:,1]
# y_prediction = estimator.predict(test_x)
y_prediction
# Out:
# array([0.4184294 , 0.21896407, 0.34382915, 0.00296344, 0.16611648,
#        0.12159458, 0.82055825, 0.04721903, 0.259512  , 0.09369763,
#        0.04309604, 0.0836821 , 0.09491436, 0.05826006, 0.17279636,
#        0.06460423, 0.09563568, 0.08854944, 0.08737417, 0.06528149,
#        1.        , 0.15612321, 0.11988204, 0.06679686, 0.07533306,
#        0.08371553, 0.16857332, 0.07345042, 0.12481851, 0.13885831,
#        0.06973241, 0.0892082 , 0.21693009])

# %%
test_x.shape
# Out:
# (33, 19)

# %%
train_x.shape
# Out:
# (113, 19)

# %%
# df_m1 = df_train.fillna(-1)
# df_m1 = StandardScaler().fit_transform(df_m1)
# train_x = df_m1[:train_num]
# clf = GradientBoostingClassifier()
# clf.fit(train_x,train_y)

# %%
# test_feature = []
# for dtype,feature in zip(df_test.dtypes,df_test.columns):
#     if dtype == 'float64' or dtype == 'int64':
#         test_feature.append(feature)
# df_test = df_test[test_feature]
# df_test = df_test.fillna(-1)
# test_x = StandardScaler().fit_transform(df_test)
# #預測結果
# y_prediction = clf.predict_proba(test_x)

# y_prediction

# %%
# df_answer['poi'] = y_prediction

for i in range(0,len(y_prediction)):
    df_answer['poi'][i] = y_prediction[i]
    

df_answer

filename = './submission.csv'

df_answer.to_csv(filename, index=False)
# Out:
# <ipython-input-191-294badb1a834>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_answer['poi'][i] = y_prediction[i]
